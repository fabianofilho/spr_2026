# %% [markdown]
# # SPR 2026 - Download de Dados
#
# Execute este notebook **uma única vez** para baixar os dados do Kaggle e salvar no Google Drive.
#
# Depois, os outros notebooks usarão os dados salvos no Drive.

# %%
# Montar Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Diretório base no Drive
DRIVE_BASE = '/content/drive/MyDrive/SPR_2026_outputs'
DATA_DIR = f'{DRIVE_BASE}/data'

import os
os.makedirs(DATA_DIR, exist_ok=True)
print(f"Diretório de dados: {DATA_DIR}")

# %%
# Verificar se dados já existem
train_path = f'{DATA_DIR}/train.csv'

if os.path.exists(train_path):
    print("✅ Dados já existem no Drive!")
    # !ls -la {DATA_DIR}
else:
    print("📥 Baixando dados do Kaggle...")

# %%
# Configurar API Kaggle
# !pip install kaggle -q

from google.colab import userdata
os.environ['KAGGLE_USERNAME'] = userdata.get('KAGGLE_USERNAME')
os.environ['KAGGLE_KEY'] = userdata.get('KAGGLE_KEY')

# !mkdir -p ~/.kaggle
# !echo '{"username":"'$KAGGLE_USERNAME'","key":"'$KAGGLE_KEY'"}' > ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

print("✅ API Kaggle configurada")

# %%
# Download do dataset
# !kaggle competitions download -c spr-2026-mammography-report-classification -p /tmp/

# Extrair para o Drive
# !unzip -o /tmp/spr-2026-mammography-report-classification.zip -d {DATA_DIR}

# Limpar arquivo zip
# !rm /tmp/spr-2026-mammography-report-classification.zip

print("\n✅ Download concluído!")

# %%
# Verificar arquivos
print("Arquivos no diretório de dados:")
# !ls -la {DATA_DIR}

import pandas as pd
train = pd.read_csv(f'{DATA_DIR}/train.csv')
print(f"\n✅ Train shape: {train.shape}")
print(f"Colunas: {train.columns.tolist()}")

# %% [markdown]
# ## Pronto!
#
# Os dados foram salvos em: `/content/drive/MyDrive/SPR_2026_outputs/data/`
#
# Agora você pode executar os outros notebooks (01_eda, 02_tfidf, etc.) que usarão esses dados automaticamente.
